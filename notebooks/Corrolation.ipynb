# %%
from matplotlib import pyplot as plt
from scipy import stats
# %pylab inline

# %%
x = np.random.randn(1000)

# %%
y = np.random.randn(1000)

# %%
plt.scatter(x,y)

# %%
stats.pearsonr(x, y)
# Out:
# (-0.033942430256804393, 0.28357614417036675)

# %%
y = (1.2* x ) + (.4* np.random.randn(1000))

# %%
y = (1.2* x ) + (.3* np.random.randn(1000));fig = figure(); fig.add_subplot(1,1,1,aspect='equal');plt.scatter(x,y)

# %%
stats.pearsonr(x, y)
# Out:
# (0.96899738977914707, 0.0)

# %%
y = (1.2* x ) + (.6* np.random.randn(1000));fig = figure(); fig.add_subplot(1,1,1,aspect='equal');plt.scatter(x,y)

# %%
stats.pearsonr(x, y)
# Out:
# (0.89303630558146885, 0.0)

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import scipy.stats as st

# %%
x = np.random.randn(1000)

# %%
y = np.random.randn(1000)

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.scatter(x,y)

# %%
st.pearsonr(x, y)
# Out:
# (-0.064268203984495356, 0.042163981164269657)

# %%
y = (1.2* x ) + (.3* np.random.randn(1000))
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.scatter(x,y)
ax.set_aspect('equal') # square axis

# %%
st.pearsonr(x, y)
# Out:
# (0.96707412473814114, 0.0)

# %%
y = (-1.2* x ) + (.6* np.random.randn(1000))
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.scatter(x,y)
ax.set_aspect('equal') # square axis
slope, intercept, _, _, _ = st.linregress(x,y)
print slope, intercept
ax.plot(x, slope*x+intercept, color='y')
# Out:
# -1.18122105066 -0.0206258509339

# %%
y = (1.2* x ) + (.4* np.random.randn(1000))

# %%
st.pearsonr(x, y)
# Out:
# (-0.8811989983267241, 0.0)
